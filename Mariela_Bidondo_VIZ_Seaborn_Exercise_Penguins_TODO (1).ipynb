# %% [markdown]
# #**WELCOME TO THE ANTARTICA**

# %% [markdown]
# ![texto alternativo](https://images.pexels.com/photos/48178/mountains-ice-bergs-antarctica-berg-48178.jpeg?auto=compress&cs=tinysrgb&dpr=2&h=750&w=1260)

# %% [markdown]
# *   After finishing IMMUNE Bootcamp you have been actively applying for different DS positions where to put in practice your new skills. Today you finally received an acceptance letter from the **National Biology Center** and are required to joined them as soon as possible.
#
#
# *   The NBC is currently doing a researh on the **Antartica** penguin population. They need to **identify the amount of penguins belonging to each different species as well as it sex** in order to identify whether global warming is impacting their spread.
#
#
# *   NBC's main challenge is the great amount of time it takes to train a biologist to **identify different penguin species and their sex**. They believe just comparing different penguin basic characteristics they should be able to recognize each penguin's sex and species.
#
# *   They provide you with a **dataset of the last expedition** where you can see both these characteristics for each penguin as well as the sex and specieces already determined by an expert biologist.
#
# *   They also provide you with some extra documentation on penguins basic knowledge:

# %% [markdown]
# ![texto alternativo](https://allisonhorst.github.io/palmerpenguins/articles/articles/img/lter_penguins.png)
#
#
# Artwork by @allison_horst

# %% [markdown]
# ![texto alternativo](https://ecdn.teacherspayteachers.com/thumbitem/Parts-of-a-Penguin-Matching-Cards-Activities-Montesorri-Style-Hands-on-2940033-1486413093/original-2940033-2.jpg)
#
#
# https://ecdn.teacherspayteachers.com

# %% [markdown]
# ![texto alternativo](https://allisonhorst.github.io/palmerpenguins/articles/articles/img/culmen_depth.png)
#
#
#
#
# Artwork by @allison_horst

# %% [markdown]
# ![texto alternativo](https://www.zegrahm.com/sites/zeg/files/styles/d2_hero_fp_scale_and_crop_2400x800/public/image509.jpeg?t=1JeDLu&itok=Mt9U-lhp)

# %% [markdown]
# https://www.google.com/maps/d/edit?mid=1TXC1N8z-uv3lD2YKpoicrzTaR3Lc7qfR&usp=sharing

# %% [markdown]
# ##**Setup**

# %% [markdown]
# ###**EXERCISE 1**: *

# %% [markdown]
# Import matplotlib, numpy, pandas and seaborn and set your favourite seaborn style:

# %%
#CODE HERE
import matplotlib as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ###**EXERCISE 2**: *

# %% [markdown]
# Import the penguins built-in dataset:

# %%
#CODE HERE
penguins_ds = sns.load_dataset('penguins')
#Importamos el data set desde la libreria de Seaborn
penguins_ds.head()
# Out:
#   species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1  ...              181.0       3750.0    Male
# 1  Adelie  Torgersen            39.5  ...              186.0       3800.0  Female
# 2  Adelie  Torgersen            40.3  ...              195.0       3250.0  Female
# 3  Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4  Adelie  Torgersen            36.7  ...              193.0       3450.0  Female
#
# [5 rows x 7 columns]

# %% [markdown]
# ##**Initial Understanding**

# %% [markdown]
# You may answer these questions using Pandas.

# %% [markdown]
# ###**EXERCISE 3**: *

# %% [markdown]
# Use Pandas to see a sumary of the data (amount of observations, column names, data types...)

# %%
#CODE HERE
penguins_ds.info()
penguins_ds.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# ###**EXERCISE 4**: *

# %% [markdown]
# Remove empty values before jumping into the data:

# %%
#CODE HERE
penguins_ds.dropna()
# Out:
#     species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0    Adelie  Torgersen            39.1  ...              181.0       3750.0    Male
# 1    Adelie  Torgersen            39.5  ...              186.0       3800.0  Female
# 2    Adelie  Torgersen            40.3  ...              195.0       3250.0  Female
# 4    Adelie  Torgersen            36.7  ...              193.0       3450.0  Female
# 5    Adelie  Torgersen            39.3  ...              190.0       3650.0    Male
# ..      ...        ...             ...  ...                ...          ...     ...
# 338  Gentoo     Biscoe            47.2  ...              214.0       4925.0  Female
# 340  Gentoo     Biscoe            46.8  ...              215.0       4850.0  Female
# 341  Gentoo     Biscoe            50.4  ...              222.0       5750.0    Male
# 342  Gentoo     Biscoe            45.2  ...              212.0       5200.0  Female
# 343  Gentoo     Biscoe            49.9  ...              213.0       5400.0    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# ###**EXERCISE 5**: *

# %% [markdown]
# Which are the possible values for each categorical column?

# %%
#CODE HERE

data = {'Unique Species': pd.unique(penguins_ds.species),
        'Unique Islands': pd.unique(penguins_ds.island) ,
         'Unique Sex': pd.unique(penguins_ds.sex)
        }

dfUnique = pd.DataFrame(data, columns = ["Unique Species",'Unique Islands','Unique Sex'])

print (dfUnique)
# Out:
#   Unique Species Unique Islands Unique Sex
# 0         Adelie      Torgersen       Male
# 1      Chinstrap         Biscoe     Female
# 2         Gentoo          Dream        NaN

# %% [markdown]
# What are the main characteristics of each numerical column?

# %%
#CODE HERE
penguins_ds.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# ##**Basic Plotting**

# %% [markdown]
# On this section you will have to answer the questions by drawing plots that show the answer:

# %% [markdown]
# ###**EXERCISE 6**: *

# %% [markdown]
# How many penguins belong to each species group?

# %%
#CODE HERE
sns.countplot(data= penguins_ds,
              x='species');

# %% [markdown]
# How many penguins belong to each species group per sex?

# %%
#CODE HERE
sns.countplot(data= penguins_ds,
              x='species', 
              hue='sex');

# %% [markdown]
# How many penguins belong to each species group per island?

# %%
#CODE HERE
sns.countplot(data= penguins_ds,
              x='species', 
              hue='island');

# %% [markdown]
# Write down your conclusions:

# %% [markdown]
# Chinstrap es la especie con menor numero de pingüinos, Adelie es la especie mas abundante. Esto lo podriamos asociar con su habitat, ya que lo podemos encontrar en las tres regiones de observacion. La especie Gentoo habita solamente en Biscoe y Chinstrap en la isla Dream. No hay una diferencia significativa entre el sexo de los pingüinos, la especie Gentoo es la unica que tiene una leve mayoria en machos.

# %% [markdown]
# ###**EXERCISE 7**: *

# %% [markdown]
# What is the average weight of each species?

# %%
#CODE HERE
#By default, the seaborn function sns.barplot() plots the average  of each category on the x axi

sns.barplot(data= penguins_ds,x='species', y= 'body_mass_g');

# %% [markdown]
# What is the average weight of each species per sex?

# %%
#CODE HERE
sns.barplot(data= penguins_ds,
            x='species', 
            y= 'body_mass_g', 
            hue= 'sex');

# %% [markdown]
# Write down your conclusions:

# %% [markdown]
#  Gentoo es la especie con mayor peso, mientras que entre Adelie y Chinstrap no hay una diferencia significativa de peso.Pero, en todas las especies los machos son mas pesado en promedio que las hembras.

# %% [markdown]
# ##**Statistical plotting**

# %% [markdown]
# ###**EXERCISE 8**: **

# %% [markdown]
# Build a pairplot to overview feature relationships and try to identify visually any possible pattern

# %%
#CODE HERE
sns.pairplot(data= penguins_ds);

# %% [markdown]
# Add an extra dimension to the plot by comparing species.

# %%
#CODE HERE

sns.pairplot(data= penguins_ds, hue="species");

# %% [markdown]
# Write down your conclusions:

# %% [markdown]
# Podemos ver que el tamaño de las alas y el pico tienen una fuerte relacion con el peso del pingüino. A mayor peso, mayor tamaño. La profundidad del pico tiene una relacion con la longitud pero no tan lineal. La especie Gentoo tiene una distribucion donde podemos ver dos picos, esto lo podemos atribuir a la diferencia entre pingüinos de diferente sexo.

# %% [markdown]
# Can you suggest any further similar plotting?

# %%
#CODE HERE
sns.pairplot(data= penguins_ds, hue="sex");

# %%
sns.boxplot(data=penguins_ds,
x='species',
y='flipper_length_mm',
hue='sex');

# %%
sns.boxplot(data=penguins_ds,
x='species',
y='bill_depth_mm',
hue='sex');

# %%
sns.boxplot(data=penguins_ds,
x='species',
y='bill_length_mm',
hue='sex');

# %% [markdown]
# Write down your conclusions:

# %% [markdown]
# El sexo tambien es un factor que tiene incidencia, en general las pingüas tienen una distribución mas homogénea aue los machos. Tenemos algunos outliers que podrian afectar nuestro resultado o que deberiamos de invesitgar mejor.

# %% [markdown]
# ###**EXERCISE 9**: **

# %% [markdown]
# Compare de distribution of body mass among penguin species

# %%
#CODE HERE

sns.histplot(data=penguins_ds,
             kde=True, x='body_mass_g',
             hue='species');

# %%
sns.violinplot(data=penguins_ds,
x='species',
y='body_mass_g',
split=True,      
inner='quartile',  
scale_hue=True,    
scale='count');

# %%
sns.boxplot(data=penguins_ds,
x='species',
y='body_mass_g');

# %% [markdown]
# Now take also into account species sex

# %%
#CODE HERE
sns.violinplot(data=penguins_ds,
x='species',
y='body_mass_g',
hue='sex',
split=True,  
inner='quartile',   
scale_hue=True,   
scale='count');

# %%
sns.boxplot(data=penguins_ds,
x='species',
y='body_mass_g',
hue='sex');

# %% [markdown]
# Write down your conclusions:

# %% [markdown]
# Los pingüinos Gentoo  tienen un tamaño significativamente mayor que el resto. En Gentoo y Adeline la diferencia de peso entre machos y hembras es mayor que en en los pingüinos Chinstrap.

# %% [markdown]
# ##**Report summary**

# %% [markdown]
# ###**EXERCISE 10**: **

# %% [markdown]
# What would be your feedback to the biologist lead? Are these characteristics enough to determine penguin species and sex?
#
# Did we miss any piece of information we could still study?

# %% [markdown]
# Si conocemos la isla donde encontramos el pingüino podriamos clasificarlo basandonos en su peso.
# El peso es una característica que ayudara a identificar si el pingüino es Gentoo o no. Esto no nos da un 99% de certeza, para tener una mejor respuesta deberiamos utilizar variables como el tamaño  de las alas y el pico.

# %% [markdown]
# ##**References**

# %% [markdown]
# https://github.com/allisonhorst/palmerpenguins
